# %%
from ultralytics import YOLO
import os
import torch

print("torch version:", torch.__version__)
print("CUDA available:", torch.cuda.is_available())
print("CUDA devices:", torch.cuda.device_count())
if torch.cuda.is_available():
    print("Device name:", torch.cuda.get_device_name(0))

CURRENT_DIR = os.getcwd() # yolov8_training/notebooks/train
print("Current directory: {}".format(CURRENT_DIR))
BASE_DIR = os.path.abspath(os.path.join(CURRENT_DIR, "..", "..")) # yolov8_training
print("BASE_DIR: {}".format(BASE_DIR))

DATA_YAML = os.path.join(BASE_DIR, "datasets", "binary", "data.yaml") # yolov8_training/datasets/binary/data.yaml
print("DATA_YAML: {}".format(DATA_YAML))
SAVE_DIR = os.path.join(BASE_DIR, "models", "binary_detector") # yolov8_training/datasets/models/binary_detector
print("SAVE_DIR: {}".format(SAVE_DIR))

model = YOLO(os.path.join(BASE_DIR, "notebooks", "train", "yolov8s.pt"))

print(f"Using dataset: {DATA_YAML}")
print(f"Training results will be saved in: {SAVE_DIR}")

model.train(
    data=DATA_YAML,
    epochs=100,
    imgsz=640,
    batch=8,
    project=SAVE_DIR,
    name="weights",
    device=0
)
# Out:
# torch version: 2.9.1+cu128
# CUDA available: True
# CUDA devices: 1
# Device name: NVIDIA GeForce RTX 5070
# Current directory: C:\Users\User5549\Desktop\Marija\MKD-Currency-Detector\CurrencyDetectorApp\yolov8_training\notebooks\train
# BASE_DIR: C:\Users\User5549\Desktop\Marija\MKD-Currency-Detector\CurrencyDetectorApp\yolov8_training
# DATA_YAML: C:\Users\User5549\Desktop\Marija\MKD-Currency-Detector\CurrencyDetectorApp\yolov8_training\datasets\binary\data.yaml
# SAVE_DIR: C:\Users\User5549\Desktop\Marija\MKD-Currency-Detector\CurrencyDetectorApp\yolov8_training\models\binary_detector
# Using dataset: C:\Users\User5549\Desktop\Marija\MKD-Currency-Detector\CurrencyDetectorApp\yolov8_training\datasets\binary\data.yaml
# Training results will be saved in: C:\Users\User5549\Desktop\Marija\MKD-Currency-Detector\CurrencyDetectorApp\yolov8_training\models\binary_detector
# Ultralytics 8.3.252  Python-3.11.9 torch-2.9.1+cu128 CUDA:0 (NVIDIA GeForce RTX 5070, 12227MiB)
# ...
