# %%
from pickletools import optimize
import shutil
from ultralytics import YOLO
import os

CURRENT_DIR = os.getcwd()
print(f"Current directory: {CURRENT_DIR}")

BASE_DIR = os.path.abspath(os.path.join(CURRENT_DIR, "..", ".."))
print(f"Base directory: {BASE_DIR}")

TRAINING_DIR = os.path.join(BASE_DIR, "yolov8_training", "models")

MODEL_DIR = os.path.join(BASE_DIR, "backend", "app", "models")
print(MODEL_DIR)
os.makedirs(MODEL_DIR, exist_ok=True)

models_to_export = {
    "binary": ("binary_detector", True),
    "banknote": ("banknote_detector", False),
    "coin": ("coin_detector_150", False)
}

models_to_copy = {
    "binary_detector": (True, "binary_model.pt"),
    "banknote_detector": (False, "banknote_model.pt"),
    "coin_detector_150": (False, "coin_model.pt")
}

print("="*60)
print("COPYING TRAINED MODELS TO BACKEND")
print("="*60)

for folder, (has_extra_weights, output_name) in models_to_copy.items():
    if has_extra_weights:
        source = os.path.join(TRAINING_DIR, folder, "weights", "weights", "best.pt")
    else:
        source = os.path.join(TRAINING_DIR, folder, "weights", "best.pt")

    model = YOLO(source)
    exported_path = model.export(format="torchscript", device="cuda", imgsz=640)
    print(f"  Exported to: {exported_path}")

    destination = os.path.join(MODEL_DIR, f"{folder}_model.pt")
    shutil.move(exported_path, destination)

    print(f"  ✓ Successfully moved to: {destination}")

    print(f"\n{folder}:")
    print(f"  From: {source}")
    print(f"  To:   {destination}")

for name, (folder, has_extra_weights) in models_to_export.items():
    if has_extra_weights:
        weights = os.path.join(TRAINING_DIR, folder, "weights", "weights", "best.pt")
    else:
        weights = os.path.join(TRAINING_DIR, folder, "weights", "best.pt")

    if not os.path.exists(weights):
        print(f"  ✗ File not found!")
        continue

    try:
        model = YOLO(weights)
        exported_path = model.export(format="torchscript", device="cuda", imgsz=640)
        print(f"  Exported to: {exported_path}")

        destination = os.path.join(MODEL_DIR, f"{name}_model.torchscript")
        shutil.move(exported_path, destination)

        print(f"  ✓ Successfully moved to: {destination}")
    except Exception as e:
        print(f"  ✗ Error: {e}")
# Out:
# Current directory: C:\Users\User5549\Desktop\Marija\MKD-Currency-Detector\CurrencyDetectorApp\yolov8_training\notebooks
# Base directory: C:\Users\User5549\Desktop\Marija\MKD-Currency-Detector\CurrencyDetectorApp
# C:\Users\User5549\Desktop\Marija\MKD-Currency-Detector\CurrencyDetectorApp\backend\app\models
# ============================================================
# COPYING TRAINED MODELS TO BACKEND
# ============================================================
# Ultralytics 8.3.241  Python-3.11.9 torch-2.9.1+cu128 CUDA:0 (NVIDIA GeForce RTX 5070, 12227MiB)
# Model summary (fused): 72 layers, 11,126,358 parameters, 0 gradients, 28.4 GFLOPs
#
# PyTorch: starting from 'C:\Users\User5549\Desktop\Marija\MKD-Currency-Detector\CurrencyDetectorApp\yolov8_training\models\binary_detector\weights\weights\best.pt' with input shape (1, 3, 640, 640) BCHW and output shape(s) (1, 6, 8400) (21.5 MB)
#
# TorchScript: starting export with torch 2.9.1+cu128...
# TorchScript: export success  0.9s, saved as 'C:\Users\User5549\Desktop\Marija\MKD-Currency-Detector\CurrencyDetectorApp\yolov8_training\models\binary_detector\weights\weights\best.torchscript' (42.9 MB)
#
# Export complete (1.1s)
# Results saved to C:\Users\User5549\Desktop\Marija\MKD-Currency-Detector\CurrencyDetectorApp\yolov8_training\models\binary_detector\weights\weights
# Predict:         yolo predict task=detect model=C:\Users\User5549\Desktop\Marija\MKD-Currency-Detector\CurrencyDetectorApp\yolov8_training\models\binary_detector\weights\weights\best.torchscript imgsz=640
# Validate:        yolo val task=detect model=C:\Users\User5549\Desktop\Marija\MKD-Currency-Detector\CurrencyDetectorApp\yolov8_training\models\binary_detector\weights\weights\best.torchscript imgsz=640 data=C:\Users\User5549\Desktop\Marija\MKD-Currency-Detector\CurrencyDetectorApp\yolov8_training\datasets\binary\data.yaml
# Visualize:       https://netron.app
#   Exported to: C:\Users\User5549\Desktop\Marija\MKD-Currency-Detector\CurrencyDetectorApp\yolov8_training\models\binary_detector\weights\weights\best.torchscript
#   ✓ Successfully moved to: C:\Users\User5549\Desktop\Marija\MKD-Currency-Detector\CurrencyDetectorApp\backend\app\models\binary_detector_model.pt
#
# binary_detector:
#   From: C:\Users\User5549\Desktop\Marija\MKD-Currency-Detector\CurrencyDetectorApp\yolov8_training\models\binary_detector\weights\weights\best.pt
#   To:   C:\Users\User5549\Desktop\Marija\MKD-Currency-Detector\CurrencyDetectorApp\backend\app\models\binary_detector_model.pt
# Ultralytics 8.3.241  Python-3.11.9 torch-2.9.1+cu128 CUDA:0 (NVIDIA GeForce RTX 5070, 12227MiB)
# Model summary (fused): 72 layers, 11,128,293 parameters, 0 gradients, 28.5 GFLOPs
#
# PyTorch: starting from 'C:\Users\User5549\Desktop\Marija\MKD-Currency-Detector\CurrencyDetectorApp\yolov8_training\models\banknote_detector\weights\best.pt' with input shape (1, 3, 640, 640) BCHW and output shape(s) (1, 11, 8400) (21.5 MB)
#
# TorchScript: starting export with torch 2.9.1+cu128...
# TorchScript: export success  0.7s, saved as 'C:\Users\User5549\Desktop\Marija\MKD-Currency-Detector\CurrencyDetectorApp\yolov8_training\models\banknote_detector\weights\best.torchscript' (42.9 MB)
#
# Export complete (0.8s)
# Results saved to C:\Users\User5549\Desktop\Marija\MKD-Currency-Detector\CurrencyDetectorApp\yolov8_training\models\banknote_detector\weights
# Predict:         yolo predict task=detect model=C:\Users\User5549\Desktop\Marija\MKD-Currency-Detector\CurrencyDetectorApp\yolov8_training\models\banknote_detector\weights\best.torchscript imgsz=640
# Validate:        yolo val task=detect model=C:\Users\User5549\Desktop\Marija\MKD-Currency-Detector\CurrencyDetectorApp\yolov8_training\models\banknote_detector\weights\best.torchscript imgsz=640 data=C:\Users\User5549\Desktop\Marija\MKD-Currency-Detector\CurrencyDetectorApp\yolov8_training\datasets\banknote\data.yaml
# Visualize:       https://netron.app
#   Exported to: C:\Users\User5549\Desktop\Marija\MKD-Currency-Detector\CurrencyDetectorApp\yolov8_training\models\banknote_detector\weights\best.torchscript
#   ✓ Successfully moved to: C:\Users\User5549\Desktop\Marija\MKD-Currency-Detector\CurrencyDetectorApp\backend\app\models\banknote_detector_model.pt
#
# banknote_detector:
#   From: C:\Users\User5549\Desktop\Marija\MKD-Currency-Detector\CurrencyDetectorApp\yolov8_training\models\banknote_detector\weights\best.pt
#   To:   C:\Users\User5549\Desktop\Marija\MKD-Currency-Detector\CurrencyDetectorApp\backend\app\models\banknote_detector_model.pt
# Ultralytics 8.3.241  Python-3.11.9 torch-2.9.1+cu128 CUDA:0 (NVIDIA GeForce RTX 5070, 12227MiB)
# Model summary (fused): 72 layers, 11,127,519 parameters, 0 gradients, 28.4 GFLOPs
#
# PyTorch: starting from 'C:\Users\User5549\Desktop\Marija\MKD-Currency-Detector\CurrencyDetectorApp\yolov8_training\models\coin_detector_150\weights\best.pt' with input shape (1, 3, 640, 640) BCHW and output shape(s) (1, 9, 8400) (21.5 MB)
#
# TorchScript: starting export with torch 2.9.1+cu128...
# TorchScript: export success  1.0s, saved as 'C:\Users\User5549\Desktop\Marija\MKD-Currency-Detector\CurrencyDetectorApp\yolov8_training\models\coin_detector_150\weights\best.torchscript' (42.9 MB)
#
# Export complete (1.1s)
# Results saved to C:\Users\User5549\Desktop\Marija\MKD-Currency-Detector\CurrencyDetectorApp\yolov8_training\models\coin_detector_150\weights
# Predict:         yolo predict task=detect model=C:\Users\User5549\Desktop\Marija\MKD-Currency-Detector\CurrencyDetectorApp\yolov8_training\models\coin_detector_150\weights\best.torchscript imgsz=640
# Validate:        yolo val task=detect model=C:\Users\User5549\Desktop\Marija\MKD-Currency-Detector\CurrencyDetectorApp\yolov8_training\models\coin_detector_150\weights\best.torchscript imgsz=640 data=C:\Users\User5549\Desktop\Marija\MKD-Currency-Detector\CurrencyDetectorApp\yolov8_training\datasets\coin\data.yaml
# Visualize:       https://netron.app
#   Exported to: C:\Users\User5549\Desktop\Marija\MKD-Currency-Detector\CurrencyDetectorApp\yolov8_training\models\coin_detector_150\weights\best.torchscript
#   ✓ Successfully moved to: C:\Users\User5549\Desktop\Marija\MKD-Currency-Detector\CurrencyDetectorApp\backend\app\models\coin_detector_150_model.pt
#
# coin_detector_150:
#   From: C:\Users\User5549\Desktop\Marija\MKD-Currency-Detector\CurrencyDetectorApp\yolov8_training\models\coin_detector_150\weights\best.pt
#   To:   C:\Users\User5549\Desktop\Marija\MKD-Currency-Detector\CurrencyDetectorApp\backend\app\models\coin_detector_150_model.pt
# Ultralytics 8.3.241  Python-3.11.9 torch-2.9.1+cu128 CUDA:0 (NVIDIA GeForce RTX 5070, 12227MiB)
# Model summary (fused): 72 layers, 11,126,358 parameters, 0 gradients, 28.4 GFLOPs
#
# PyTorch: starting from 'C:\Users\User5549\Desktop\Marija\MKD-Currency-Detector\CurrencyDetectorApp\yolov8_training\models\binary_detector\weights\weights\best.pt' with input shape (1, 3, 640, 640) BCHW and output shape(s) (1, 6, 8400) (21.5 MB)
#
# TorchScript: starting export with torch 2.9.1+cu128...
# TorchScript: export success  0.7s, saved as 'C:\Users\User5549\Desktop\Marija\MKD-Currency-Detector\CurrencyDetectorApp\yolov8_training\models\binary_detector\weights\weights\best.torchscript' (42.9 MB)
#
# Export complete (0.8s)
# Results saved to C:\Users\User5549\Desktop\Marija\MKD-Currency-Detector\CurrencyDetectorApp\yolov8_training\models\binary_detector\weights\weights
# Predict:         yolo predict task=detect model=C:\Users\User5549\Desktop\Marija\MKD-Currency-Detector\CurrencyDetectorApp\yolov8_training\models\binary_detector\weights\weights\best.torchscript imgsz=640
# Validate:        yolo val task=detect model=C:\Users\User5549\Desktop\Marija\MKD-Currency-Detector\CurrencyDetectorApp\yolov8_training\models\binary_detector\weights\weights\best.torchscript imgsz=640 data=C:\Users\User5549\Desktop\Marija\MKD-Currency-Detector\CurrencyDetectorApp\yolov8_training\datasets\binary\data.yaml
# Visualize:       https://netron.app
#   Exported to: C:\Users\User5549\Desktop\Marija\MKD-Currency-Detector\CurrencyDetectorApp\yolov8_training\models\binary_detector\weights\weights\best.torchscript
#   ✓ Successfully moved to: C:\Users\User5549\Desktop\Marija\MKD-Currency-Detector\CurrencyDetectorApp\backend\app\models\binary_model.torchscript
# Ultralytics 8.3.241  Python-3.11.9 torch-2.9.1+cu128 CUDA:0 (NVIDIA GeForce RTX 5070, 12227MiB)
# Model summary (fused): 72 layers, 11,128,293 parameters, 0 gradients, 28.5 GFLOPs
#
# PyTorch: starting from 'C:\Users\User5549\Desktop\Marija\MKD-Currency-Detector\CurrencyDetectorApp\yolov8_training\models\banknote_detector\weights\best.pt' with input shape (1, 3, 640, 640) BCHW and output shape(s) (1, 11, 8400) (21.5 MB)
#
# TorchScript: starting export with torch 2.9.1+cu128...
# TorchScript: export success  0.7s, saved as 'C:\Users\User5549\Desktop\Marija\MKD-Currency-Detector\CurrencyDetectorApp\yolov8_training\models\banknote_detector\weights\best.torchscript' (42.9 MB)
#
# Export complete (0.8s)
# Results saved to C:\Users\User5549\Desktop\Marija\MKD-Currency-Detector\CurrencyDetectorApp\yolov8_training\models\banknote_detector\weights
# Predict:         yolo predict task=detect model=C:\Users\User5549\Desktop\Marija\MKD-Currency-Detector\CurrencyDetectorApp\yolov8_training\models\banknote_detector\weights\best.torchscript imgsz=640
# Validate:        yolo val task=detect model=C:\Users\User5549\Desktop\Marija\MKD-Currency-Detector\CurrencyDetectorApp\yolov8_training\models\banknote_detector\weights\best.torchscript imgsz=640 data=C:\Users\User5549\Desktop\Marija\MKD-Currency-Detector\CurrencyDetectorApp\yolov8_training\datasets\banknote\data.yaml
# Visualize:       https://netron.app
#   Exported to: C:\Users\User5549\Desktop\Marija\MKD-Currency-Detector\CurrencyDetectorApp\yolov8_training\models\banknote_detector\weights\best.torchscript
#   ✓ Successfully moved to: C:\Users\User5549\Desktop\Marija\MKD-Currency-Detector\CurrencyDetectorApp\backend\app\models\banknote_model.torchscript
# Ultralytics 8.3.241  Python-3.11.9 torch-2.9.1+cu128 CUDA:0 (NVIDIA GeForce RTX 5070, 12227MiB)
# Model summary (fused): 72 layers, 11,127,519 parameters, 0 gradients, 28.4 GFLOPs
#
# PyTorch: starting from 'C:\Users\User5549\Desktop\Marija\MKD-Currency-Detector\CurrencyDetectorApp\yolov8_training\models\coin_detector_150\weights\best.pt' with input shape (1, 3, 640, 640) BCHW and output shape(s) (1, 9, 8400) (21.5 MB)
#
# TorchScript: starting export with torch 2.9.1+cu128...
# TorchScript: export success  0.6s, saved as 'C:\Users\User5549\Desktop\Marija\MKD-Currency-Detector\CurrencyDetectorApp\yolov8_training\models\coin_detector_150\weights\best.torchscript' (42.9 MB)
#
# Export complete (0.7s)
# Results saved to C:\Users\User5549\Desktop\Marija\MKD-Currency-Detector\CurrencyDetectorApp\yolov8_training\models\coin_detector_150\weights
# Predict:         yolo predict task=detect model=C:\Users\User5549\Desktop\Marija\MKD-Currency-Detector\CurrencyDetectorApp\yolov8_training\models\coin_detector_150\weights\best.torchscript imgsz=640
# Validate:        yolo val task=detect model=C:\Users\User5549\Desktop\Marija\MKD-Currency-Detector\CurrencyDetectorApp\yolov8_training\models\coin_detector_150\weights\best.torchscript imgsz=640 data=C:\Users\User5549\Desktop\Marija\MKD-Currency-Detector\CurrencyDetectorApp\yolov8_training\datasets\coin\data.yaml
# Visualize:       https://netron.app
#   Exported to: C:\Users\User5549\Desktop\Marija\MKD-Currency-Detector\CurrencyDetectorApp\yolov8_training\models\coin_detector_150\weights\best.torchscript
#   ✓ Successfully moved to: C:\Users\User5549\Desktop\Marija\MKD-Currency-Detector\CurrencyDetectorApp\backend\app\models\coin_model.torchscript
